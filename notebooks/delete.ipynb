# %%
from telegram.ext import Updater
from telegram.ext import CommandHandler
import logging #debug
from telega.dixit.config import TOKEN

# parse bot
updater = Updater(token=TOKEN, use_context=True)

dispatcher = updater.dispatcher

# set debug logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                     level=logging.INFO)

def start(update, context):
    context.bot.send_message(chat_id=update.effective_chat.id, text="I'm a Dixit bot, the game!")


# define start handler
start_handler = CommandHandler('start', start)
# add it to bot
dispatcher.add_handler(start_handler)



updater.start_polling()
# Out:
# 2020-11-13 13:22:33,064 - apscheduler.scheduler - INFO - Scheduler started
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     616                                                   body=body, headers=headers,
# --> 617                                                   chunked=chunked)
#     618
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     359         try:
# --> 360             self._validate_conn(conn)
#     361         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in _validate_conn(self, conn)
#     856         """
# --> 857         super(HTTPSConnectionPool, self)._validate_conn(conn)
#     858
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in _validate_conn(self, conn)
#     288         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 289             conn.connect()
#     290
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     323     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 324         return context.wrap_socket(sock, server_hostname=server_hostname)
#     325
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1051)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\utils\request.py in _request_wrapper(self, *args, **kwargs)
#     229         try:
# --> 230             resp = self._con_pool.request(*args, **kwargs)
#     231         except urllib3.exceptions.TimeoutError:
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      69                                             headers=headers,
# ---> 70                                             **urlopen_kw)
#      71
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     147
# --> 148         return self.urlopen(method, url, **extra_kw)
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     243         else:
# --> 244             response = conn.urlopen(method, u.request_uri, **kw)
#     245
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     646             clean_exit = False
# --> 647             raise SSLError(e)
#     648
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1051)
#
# During handling of the above exception, another exception occurred:
#
# NetworkError                              Traceback (most recent call last)
# <ipython-input-6-c4284d59001a> in <module>()
#      24
#      25
# ---> 26 updater.start_polling()
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\ext\updater.py in start_polling(self, poll_interval, timeout, clean, bootstrap_retries, read_latency, allowed_updates)
#     270                 dispatcher_ready = Event()
#     271                 polling_ready = Event()
# --> 272                 self._init_thread(self.dispatcher.start, "dispatcher", ready=dispatcher_ready)
#     273                 self._init_thread(self._start_polling, "updater", poll_interval, timeout,
#     274                                   read_latency, bootstrap_retries, clean, allowed_updates,
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\ext\updater.py in _init_thread(self, target, name, *args, **kwargs)
#     213     def _init_thread(self, target: Callable, name: str, *args: Any, **kwargs: Any) -> None:
#     214         thr = Thread(target=self._thread_wrapper,
# --> 215                      name="Bot:{}:{}".format(self.bot.id, name),
#     216                      args=(target,) + args,
#     217                      kwargs=kwargs)
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\bot.py in decorator(self, *args, **kwargs)
#      60     def decorator(self: 'Bot', *args: Any, **kwargs: Any) -> RT:
#      61         if not self.bot:
# ---> 62             self.get_me()
#      63
#      64         if self._commands is None:
#
# <decorator-gen-123> in get_me(self, timeout, api_kwargs)
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\bot.py in decorator(self, *args, **kwargs)
#      76     def decorator(self: 'Bot', *args: Any, **kwargs: Any) -> RT:
#      77         logger.debug('Entering: %s', func.__name__)
# ---> 78         result = func(*args, **kwargs)
#      79         logger.debug(result)
#      80         logger.debug('Exiting: %s', func.__name__)
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\bot.py in get_me(self, timeout, api_kwargs)
#     324
#     325         """
# --> 326         result = self._post('getMe', timeout=timeout, api_kwargs=api_kwargs)
#     327
#     328         self.bot = User.de_json(result, self)  # type: ignore
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\bot.py in _post(self, endpoint, data, timeout, api_kwargs)
#     183
#     184         return self.request.post('{}/{}'.format(self.base_url, endpoint), data=data,
# --> 185                                  timeout=timeout)
#     186
#     187     def _message(self,
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\utils\request.py in post(self, url, data, timeout)
#     326                                            body=json.dumps(data).encode('utf-8'),
#     327                                            headers={'Content-Type': 'application/json'},
# --> 328                                            **urlopen_kwargs)
#     329
#     330         return self._parse(result)
#
# c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telegram\utils\request.py in _request_wrapper(self, *args, **kwargs)
#     234             # HTTPError must come last as its the base urllib3 exception class
#     235             # TODO: do something smart here; for now just raise NetworkError
# --> 236             raise NetworkError('urllib3 HTTPError {}'.format(error))
#     237
#     238         if 200 <= resp.status <= 299:
#
# NetworkError: urllib3 HTTPError [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1051)

# %%
bot
