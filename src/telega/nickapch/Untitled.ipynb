# %%
import bot
import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bot.bot.polling(none_stop=True)
# Out:
# 2020-05-10 17:10:17,537 (util.py:68 PollingThread) ERROR - TeleBot: "ApiException occurred, args=('A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:\n[b\'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}\']',)
# Traceback (most recent call last):
#   File "c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telebot\util.py", line 62, in run
#     task(*args, **kwargs)
#   File "c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telebot\__init__.py", line 281, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "c:\users\mkapchenko\appdata\local\programs\python\python37\lib\site-packages\telebot\__init__.py", line 251, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
# ...
